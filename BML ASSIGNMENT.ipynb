# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("Stock_Market.csv")
data.head(10)
# Out:
#          Date Symbol  Prev Close    Open     High      Low    Last    Close  \
# 0  01-01-2018    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60
# 1  02-01-2018    TCS     2645.60  2660.0  2669.60  2620.20     NaN  2631.20
# 2  03-01-2018    TCS     2631.20  2632.0      NaN  2631.20  2639.0  2638.65
# 3  04-01-2018    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10
# 4  05-01-2018    TCS         NaN  2650.0  2699.50  2650.00  2695.0  2689.20
# 5  08-01-2018    TCS         NaN  2700.0  2726.85  2681.85  2708.8  2714.40
# 6  09-01-2018    TCS     2714.40  2715.0  2721.00  2676.55     NaN  2709.00
# 7  10-01-2018    TCS         NaN  2711.0  2816.00  2694.65  2803.0  2806.60
# 8  11-01-2018    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50
# 9  12-01-2018    TCS     2790.50     NaN  2805.00  2740.55  2769.9  2776.35
#
#       VWAP     Volume      Turnover   Trades  Deliverable Volume  %Deliverble
# ...

# %%
data.isnull().sum()
# Out:
# Date                  82
# Symbol                 0
# Prev Close            82
# Open                  82
# High                  82
# Low                   82
# Last                  82
# Close                 82
# VWAP                  82
# Volume                82
# Turnover              82
# Trades                82
# Deliverable Volume    82
# %Deliverble           82
# dtype: int64

# %%
print(data.describe())
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   741.000000   741.000000   741.000000   741.000000   741.000000
# mean   2339.915722  2340.403711  2365.234008  2323.734750  2346.567206
# std     470.619573   474.870838   474.735125   476.880182   476.582188
# min    1636.350000  1559.700000  1685.450000  1506.050000  1631.000000
# 25%    2008.500000  2010.000000  2024.900000  1985.000000  2009.850000
# 50%    2164.850000  2163.650000  2186.000000  2146.550000  2167.500000
# 75%    2711.550000  2700.000000  2732.950000  2705.000000  2726.000000
# max    3603.700000  3625.000000  3674.800000  3572.550000  3610.750000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count   741.000000   741.000000  7.410000e+02  7.410000e+02     741.000000
# mean   2346.097976  2354.287679  3.212608e+06  7.549054e+14  139248.554656
# std     474.006733   478.228933  2.510535e+06  6.609702e+14   62416.080059
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                741 non-null    object
#  1   Symbol              823 non-null    object
#  2   Prev Close          741 non-null    float64
#  3   Open                741 non-null    float64
#  4   High                741 non-null    float64
#  5   Low                 741 non-null    float64
#  6   Last                741 non-null    float64
#  7   Close               741 non-null    float64
#  8   VWAP                741 non-null    float64
#  9   Volume              741 non-null    float64
#  10  Turnover            741 non-null    float64
#  11  Trades              741 non-null    float64
#  12  Deliverable Volume  741 non-null    float64
#  13  %Deliverble         741 non-null    float64
# dtypes: float64(12), object(2)
# memory usage: 90.1+ KB
# None

# %%
data.fillna(4,inplace=True)
data.head(10)
# Out:
#          Date Symbol  Prev Close    Open     High      Low    Last    Close  \
# 0  01-01-2018    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60
# 1  02-01-2018    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20
# 2  03-01-2018    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65
# 3  04-01-2018    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10
# 4  05-01-2018    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20
# 5  08-01-2018    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40
# 6  09-01-2018    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00
# 7  10-01-2018    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60
# 8  11-01-2018    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50
# 9  12-01-2018    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35
#
#       VWAP     Volume      Turnover   Trades  Deliverable Volume  %Deliverble
# ...

# %%
data.drop("Date",axis=1,inplace=True)
data.head(10)
# Out:
#   Symbol  Prev Close    Open     High      Low    Last    Close     VWAP  \
# 0    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60  2654.94
# 1    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20  2641.06
# 2    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65  2649.21
# 3    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10  2649.94
# 4    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20  2684.95
# 5    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40  2709.74
# 6    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00  2703.56
# 7    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60  2763.30
# 8    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50  2796.58
# 9    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35  2764.28
#
#       Volume      Turnover   Trades  Deliverable Volume  %Deliverble
# 0   675880.0  1.794420e+14  19464.0            330691.0       0.4893
# ...

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer=imputer.fit(data.iloc[:,1:])
data.iloc[:,1:]=imputer.transform(data.iloc[:,1:])
data.head(10)
# Out:
#   Symbol  Prev Close    Open     High      Low    Last    Close     VWAP  \
# 0    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60  2654.94
# 1    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20  2641.06
# 2    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65  2649.21
# 3    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10  2649.94
# 4    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20  2684.95
# 5    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40  2709.74
# 6    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00  2703.56
# 7    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60  2763.30
# 8    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50  2796.58
# 9    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35  2764.28
#
#       Volume      Turnover   Trades  Deliverable Volume  %Deliverble
# 0   675880.0  1.794420e+14  19464.0            330691.0       0.4893
# ...

# %%
data['label']=data['Open'].shift(4)
data.head(10)
# Out:
#   Symbol  Prev Close    Open     High      Low    Last    Close     VWAP  \
# 0    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60  2654.94
# 1    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20  2641.06
# 2    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65  2649.21
# 3    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10  2649.94
# 4    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20  2684.95
# 5    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40  2709.74
# 6    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00  2703.56
# 7    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60  2763.30
# 8    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50  2796.58
# 9    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35  2764.28
#
#       Volume      Turnover   Trades  Deliverable Volume  %Deliverble   label
# 0   675880.0  1.794420e+14  19464.0            330691.0       0.4893     NaN
# ...

# %%
data['label']=data['Open'].shift(4,fill_value=10)
data.head(10)
# Out:
#   Symbol  Prev Close    Open     High      Low    Last    Close     VWAP  \
# 0    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60  2654.94
# 1    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20  2641.06
# 2    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65  2649.21
# 3    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10  2649.94
# 4    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20  2684.95
# 5    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40  2709.74
# 6    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00  2703.56
# 7    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60  2763.30
# 8    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50  2796.58
# 9    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35  2764.28
#
#       Volume      Turnover   Trades  Deliverable Volume  %Deliverble   label
# 0   675880.0  1.794420e+14  19464.0            330691.0       0.4893    10.0
# ...

# %%
data['High'] = data['High'].fillna(data['High'].mean())
data.head(10)
# Out:
#   Symbol  Prev Close    Open     High      Low    Last    Close     VWAP  \
# 0    TCS     2701.20  2682.3  2694.80  2635.00  2650.0  2645.60  2654.94
# 1    TCS     2645.60  2660.0  2669.60  2620.20     4.0  2631.20  2641.06
# 2    TCS     2631.20  2632.0     4.00  2631.20  2639.0  2638.65  2649.21
# 3    TCS     2638.65  2650.0  2662.00  2640.00  2650.0  2657.10  2649.94
# 4    TCS        4.00  2650.0  2699.50  2650.00  2695.0  2689.20  2684.95
# 5    TCS        4.00  2700.0  2726.85  2681.85  2708.8  2714.40  2709.74
# 6    TCS     2714.40  2715.0  2721.00  2676.55     4.0  2709.00  2703.56
# 7    TCS        4.00  2711.0  2816.00  2694.65  2803.0  2806.60  2763.30
# 8    TCS     2806.60  2810.0  2821.90  2782.20  2792.5  2790.50  2796.58
# 9    TCS     2790.50     4.0  2805.00  2740.55  2769.9  2776.35  2764.28
#
#       Volume      Turnover   Trades  Deliverable Volume  %Deliverble   label
# 0   675880.0  1.794420e+14  19464.0            330691.0       0.4893    10.0
# ...

# %%
data.isnull().sum()
# Out:
# Symbol                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# label                 0
# dtype: int64
